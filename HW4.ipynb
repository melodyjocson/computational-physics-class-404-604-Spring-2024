# %%
"""Homework 3

1. Evaluate the derivative at position x using the forward difference scheme. Plot 
log(Error)=log10|f’(numerically)-f’(analytic)| against log10(dx) for dx=1e-16,1e-15,….,0.1 at 
x=π/4. You should find Error~ 𝑑𝑥𝑛 ; what is n? what is the optimal value for dx.

2.Repeat the exercise using the central difference scheme. Why this scheme is better?

3. Repeat (2) for x=0. Why do the results differ? (hint: write out the error term derived in the 
class explicitly by plugging the derivative of cos or sin)"""

# %%
#1:

# libraries 
import numpy as np 
import matplotlib.pyplot as plt

#forward difference 
def derifw(y,x,dx):
    return (y(x+dx)-y(x))/dx

#change x to pi/4
x= np.pi/4 

dxarr=[]
yarr=[]
for dx in 10**np.arange(-18, 0.1, 0.1):
    y=derifw(np.cos,x,dx)
    #print('dx %g,  y %g'%(dx,y))
    dxarr.append(dx)
    yarr.append(y)
    
#plotting 
plt.plot(dxarr, abs(yarr-(-np.sin(x))), 'b-', lw=2) 
#set plots to show log
plt.xscale('log')
plt.yscale('log')
plt.show()

# %%
At 10e16, we can see the line starts to decrease at n = 1. The optimal value for dx is approx 10e-19.

# %%
#2:


#central difference
def dericd(y,x,dx):
    return (y(x + (dx/2)) - y(x - (dx/2)))/dx

#change x to pi/4
x= np.pi/4 

dxarr=[]
yarr=[]
for dx in 10**np.arange(-17, 0.1, 0.1):
    y=dericd(np.cos,x,dx)
    #print('dx %g,  y %g'%(dx,y))
    dxarr.append(dx)
    yarr.append(y)
    
#plotting 
plt.plot(dxarr, abs(yarr-(-np.sin(x))), 'b-', lw=2) 
#set plots to show log
plt.xscale('log')
plt.yscale('log')
plt.show()

# %%
The central difference scheme is better because the forward difference due to the trucation error being smaller in
central difference compared to the forward.

# %%
#3:

#central difference
def dericd(y,x,dx):
    return (y(x + (dx/2)) - y(x - (dx/2)))/dx

#change x to 0
x= 0 

dxarr=[]
yarr=[]
for dx in 10**np.arange(-16, 0.1, 0.1):
    y=dericd(np.cos,x,dx)
    #print('dx %g,  y %g'%(dx,y))
    dxarr.append(dx)
    yarr.append(y)
    
#plotting 
plt.plot(dxarr, abs(yarr-(-np.sin(x))), 'b-', lw=2) 
#set plots to show log
plt.xscale('log')
#plt.yscale('log')
plt.show()

# %%
The results show as is because when plugging in zero into x in -sin(x) it'll always equate to 0.
